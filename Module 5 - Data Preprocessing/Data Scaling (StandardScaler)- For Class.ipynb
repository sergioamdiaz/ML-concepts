# %% [markdown]
# ## Feature Scaler - MinMaxScaler

# %% [markdown]
# ### Import the relevant libraries to use

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the data into dataframe

# %%
from pathlib import Path
Path.cwd()
# Out:
# WindowsPath('c:/Proyectos/George Brown Projects/TA/ML 1 Concepts/Module 5 - Data Preprocessing')

# %%
# Read training features into X_train
X_train=pd.read_csv('./data/X_train.csv')
# Read training target into Y_train
Y_train=pd.read_csv('./data/Y_train.csv')

# Read testing features into X_test
X_test=pd.read_csv('./data/X_test.csv')
# Read testing target into Y_test
Y_test=pd.read_csv('./data/Y_test.csv')

# Display the top 5 rows
X_train.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001032   Male      No          0      Graduate            No
# 1  LP001824   Male     Yes          1      Graduate            No
# 2  LP002928   Male     Yes          0      Graduate            No
# 3  LP001814   Male     Yes          2      Graduate            No
# 4  LP002244   Male     Yes          0      Graduate            No
# 5  LP001854   Male     Yes         3+      Graduate            No
# 6  LP002505   Male     Yes          0      Graduate            No
# 7  LP002862   Male     Yes          2  Not Graduate            No
# 8  LP001630   Male      No          0  Not Graduate            No
# 9  LP001964   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4950                0.0         125               360
# 1             2882             1843.0         123               480
# 2             3000             3416.0          56               180
# 3             9703                0.0         112               360
# 4             2333             2417.0         136               360
# 5             5250                0.0          94               360
# 6             4333             2451.0         110               360
# 7             6125             1625.0         187               480
# 8             2333             1451.0         102               480
# 9             1800             2934.0          93               360
#
#    Credit_History Property_Area
# 0               1         Urban
# 1               1     Semiurban
# 2               1     Semiurban
# 3               1         Urban
# 4               1         Urban
# 5               1         Urban
# 6               1         Urban
# 7               1     Semiurban
# 8               0         Urban
# 9               0         Urban

# %%
X_train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       384.000000         384.000000  384.000000        384.000000
# mean       5149.718750        1572.077917  141.471354        342.093750
# std        5304.921764        2624.223119   75.176271         65.846658
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3893.500000        1188.500000  128.000000        360.000000
# 75%        5819.500000        2259.250000  164.250000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History
# count      384.000000
# mean         0.856771
# std          0.350763
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Get numerical features:

# %%
num_features = X_train.select_dtypes( include = ['number']).columns
num_features
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %% [markdown]
# ## StandardScaler from Preprocessing

# %%
from sklearn import preprocessing
import numpy as np
